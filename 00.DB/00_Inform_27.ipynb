# %% [markdown]
# # 📊 Base de Dados Dinâmica — Solução Completa (Tudo em Um)
#
# Este notebook contém toda a lógica para:
# 1. **Criar tabelas** para qualquer ano automaticamente
# 2. **Inserir dados** sem duplicatas
# 3. **Inspecionar a BD** com ferramentas interativas
#
# ## ✨ Vantagens
# - ✅ Detecta automaticamente quais anos estão nos ficheiros
# - ✅ Cria tabelas para TODOS os anos (não apenas 2025/2026)
# - ✅ Insere dados em qualquer ano sem editar código
# - ✅ Protege contra duplicatas automaticamente
# - ✅ Seguro para correr múltiplas vezes
#
# ## 🚀 Modo de Usar
# Executa as células **por ordem**, uma a uma (Cell → Run All também funciona)

# %% [markdown]
# ## PASSO 1 — Importações e Configuração

# %%
# ==============================================================================
# IMPORTAÇÕES
# ==============================================================================
import platform
import sqlite3
import os
import glob
import xml.etree.ElementTree as ET
from datetime import datetime
from collections import defaultdict

print("✓ Bibliotecas importadas com sucesso")
# Out:
# ✓ Bibliotecas importadas com sucesso

# %%
# ==============================================================================
# CONFIGURAÇÃO DE CAMINHOS
# ==============================================================================

if platform.system() == 'Windows':
    DB_PATH = r"C:\Users\LISARR\Documents\python\01.Financeiro\inform_27.db"
    PASTA_FICHEIROS = r"C:\Users\LISARR\Documents\python\01.Financeiro\inform_27"
elif platform.system() == 'Darwin':
    DB_PATH = "/Volumes/RR/DB/inform_27.db"
    PASTA_FICHEIROS = "/Volumes/RR/DB/inform_27"
else:
    DB_PATH = "inform_27.db"
    PASTA_FICHEIROS = "inform_27"

print(f"DB_PATH: {DB_PATH}")
print(f"PASTA_FICHEIROS: {PASTA_FICHEIROS}")
print()

# Verificar/Criar pasta se não existir
pasta = os.path.dirname(DB_PATH)
if pasta and not os.path.exists(pasta):
    os.makedirs(pasta, exist_ok=True)
    print(f"Pasta criada: {pasta}")

# Criar BD
con = sqlite3.connect(DB_PATH)
con.close()
print(f"✓ Base de dados criada/aberta em: {DB_PATH}")
# Out:
# DB_PATH: C:\Users\LISARR\Documents\python\01.Financeiro\inform_27.db
# PASTA_FICHEIROS: C:\Users\LISARR\Documents\python\01.Financeiro\inform_27
#
# ✓ Base de dados criada/aberta em: C:\Users\LISARR\Documents\python\01.Financeiro\inform_27.db

# %%
# ==============================================================================
# DEFINIÇÕES GLOBAIS
# ==============================================================================

COLUNAS_FICHEIRO = [
    "PROPIETARIO", "TRAYECTO", "TRANSPORTISTA", "TRACTORA", "REMOLQUE",
    "INGRESODT", "COSTEDT", "RENTADT", "PALETSDT", "PESO_BRUTO",
    "CODEUT", "ESTADO_UT", "RANGO_UT", "FCARGA", "ACTIVIDAD",
    "CODEDT", "ESTADO_DT", "REFERENCIA", "CODACT", "LOCORIGEN",
    "PROV_ORIGEN", "PAISORIGEN", "CPOSTAL", "LOCDESTINO", "PROV_DESTINO",
    "PAISDESTINO", "CPOSTAD", "KM", "FENTREGA", "ORIGEN",
    "ENTREGAR", "PROV_ENTREGAR", "PAISENTREGAR", "DESTINO", "PALETS",
    "PREFAC", "RUTA", "COBROREAL", "GESTION", "DEPART",
    "USCODE", "USUARIO", "TIPOCLIENTE", "TIPOFLUJO", "WMSCODRGT",
    "LOCCAR", "LUGARCARGA", "LOCDES", "LUGARDESCARGA", "TEMP_MERC_PED",
    "TIPOPALETA", "CAMION_TIPO", "CAMION_CAPACIDAD", "TIPO_COMBUSTIBLE", "KMREALES",
    "ALBARAN",
]

COLUNA_ORIGEM = "ficheiro_origem"
CAMPO_DATA = "FENTREGA"

print(f"✓ {len(COLUNAS_FICHEIRO)} colunas definidas")
print(f"✓ Campo de data: {CAMPO_DATA}")
print(f"✓ Coluna de origem: {COLUNA_ORIGEM}")
# Out:
# ✓ 56 colunas definidas
# ✓ Campo de data: FENTREGA
# ✓ Coluna de origem: ficheiro_origem

# %% [markdown]
# ## PASSO 2 — Funções Auxiliares

# %%
# ==============================================================================
# FUNÇÃO: Ler ficheiros Excel XML
# ==============================================================================

NS = {"ss": "urn:schemas-microsoft-com:office:spreadsheet"}
SS_INDEX = "{urn:schemas-microsoft-com:office:spreadsheet}Index"

def ler_linhas_xml_spreadsheet(caminho_ficheiro):
    """
    Lê um ficheiro no formato 'Excel XML Spreadsheet 2003' e devolve
    (cabecalho, lista_de_linhas).
    """
    try:
        tree = ET.parse(caminho_ficheiro)
        root = tree.getroot()

        worksheet = root.find("ss:Worksheet", NS)
        if worksheet is None:
            return None, None

        tabela = worksheet.find("ss:Table", NS)
        if tabela is None:
            return None, None

        linhas_xml = tabela.findall("ss:Row", NS)
        if not linhas_xml:
            return [], []

        def extrair_linha(linha_xml):
            valores = []
            proximo_indice = 1
            for cell in linha_xml.findall("ss:Cell", NS):
                idx = cell.get(SS_INDEX)
                idx = int(idx) if idx is not None else proximo_indice
                while len(valores) < idx - 1:
                    valores.append(None)
                data_el = cell.find("ss:Data", NS)
                valor = data_el.text if data_el is not None else None
                valores.append(valor)
                proximo_indice = idx + 1
            return valores

        cabecalho = extrair_linha(linhas_xml[0])
        cabecalho = [c.strip() if c else f"COLUNA_{i+1}" for i, c in enumerate(cabecalho)]

        linhas = []
        n_colunas = len(cabecalho)
        for linha_xml in linhas_xml[1:]:
            valores = extrair_linha(linha_xml)
            if len(valores) < n_colunas:
                valores += [None] * (n_colunas - len(valores))
            elif len(valores) > n_colunas:
                valores = valores[:n_colunas]
            linhas.append(valores)

        return cabecalho, linhas
    except Exception as e:
        print(f"    [ERRO ao ler] {e}")
        return None, None

print("✓ Função ler_linhas_xml_spreadsheet() pronta")
# Out:
# ✓ Função ler_linhas_xml_spreadsheet() pronta

# %%
# ==============================================================================
# FUNÇÃO: Listar ficheiros Excel
# ==============================================================================

def listar_ficheiros_excel(pasta):
    """Procura todos os ficheiros .xls na pasta (incluindo subpastas)."""
    encontrados = glob.glob(os.path.join(pasta, "**", "*.xls"), recursive=True)
    vistos = set()
    ficheiros = []
    for caminho in encontrados:
        chave = os.path.normcase(os.path.abspath(caminho))
        if chave not in vistos:
            vistos.add(chave)
            ficheiros.append(caminho)
    return sorted(ficheiros)

print("✓ Função listar_ficheiros_excel() pronta")
# Out:
# ✓ Função listar_ficheiros_excel() pronta

# %%
# ==============================================================================
# FUNÇÃO: Detectar anos nos ficheiros
# ==============================================================================

def detectar_anos_nos_ficheiros(pasta):
    """
    Procura todos os ficheiros .xls na pasta e detecta quais são os anos
    presentes nos dados (através do campo FENTREGA).
    Devolve um conjunto (set) com os anos encontrados.
    """
    ficheiros = listar_ficheiros_excel(pasta)
    anos = set()
    
    idx_data = COLUNAS_FICHEIRO.index(CAMPO_DATA)
    
    for caminho in ficheiros:
        cabecalho, linhas = ler_linhas_xml_spreadsheet(caminho)
        if cabecalho is None or CAMPO_DATA not in cabecalho:
            continue
        
        for linha in linhas:
            if linha and idx_data < len(linha):
                valor_data = linha[idx_data]
                if valor_data and str(valor_data).strip()[:4].isdigit():
                    ano = str(valor_data).strip()[:4]
                    anos.add(ano)
    
    return sorted(anos)

print("✓ Função detectar_anos_nos_ficheiros() pronta")
# Out:
# ✓ Função detectar_anos_nos_ficheiros() pronta

# %%
# ==============================================================================
# FUNÇÃO: Detectar anos na BD
# ==============================================================================

def detectar_anos_na_bd(db_path):
    """
    Detecta quais são as tabelas de anos presentes na BD.
    Devolve uma lista de anos (ex: ['2023', '2024', '2025', '2026'])
    """
    con = sqlite3.connect(db_path)
    cur = con.cursor()
    
    cur.execute("SELECT name FROM sqlite_master WHERE type='table'")
    tabelas = [nome for (nome,) in cur.fetchall()]
    
    con.close()
    
    anos = []
    for tabela in tabelas:
        if tabela.startswith("inform_27_"):
            ano = tabela.replace("inform_27_", "")
            if ano.isdigit() and len(ano) == 4:
                anos.append(ano)
    
    return sorted(anos)

print("✓ Função detectar_anos_na_bd() pronta")
# Out:
# ✓ Função detectar_anos_na_bd() pronta

# %% [markdown]
# ## PASSO 3 — Criar Tabelas Dinamicamente

# %%
# ==============================================================================
# DETECTAR ANOS NOS FICHEIROS
# ==============================================================================

print("A detectar anos nos ficheiros...")
anos_detectados = detectar_anos_nos_ficheiros(PASTA_FICHEIROS)

print()
if anos_detectados:
    print(f"✓ Anos detectados: {', '.join(anos_detectados)}")
else:
    print("[AVISO] Nenhum ano detectado. Verifica se:")
    print("  - Os ficheiros .xls existem em:", PASTA_FICHEIROS)
    print("  - Têm a coluna FENTREGA")
    print("  - FENTREGA tem valores no formato AAAAMMDD")
# Out:
# A detectar anos nos ficheiros...
#
# ✓ Anos detectados: 0000, 2023, 2024, 2025, 2026

# %%
# ==============================================================================
# CRIAR TABELAS PARA CADA ANO DETECTADO
# ==============================================================================

if not anos_detectados:
    print("[ERRO] Sem anos para processar. Verifica a pasta de ficheiros.")
else:
    colunas_sql = ",\n    ".join(f'"{c}" TEXT' for c in COLUNAS_FICHEIRO)

    con = sqlite3.connect(DB_PATH)
    cur = con.cursor()

    print(f"A criar {len(anos_detectados)} tabela(s)...")
    print()
    
    for ano in anos_detectados:
        tabela_nome = f"inform_27_{ano}"
        cur.execute(f'''
            CREATE TABLE IF NOT EXISTS {tabela_nome} (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                {colunas_sql},
                "{COLUNA_ORIGEM}" TEXT
            )
        ''')
        print(f"  ✓ Tabela {tabela_nome} criada (ou já existia).")

    con.commit()
    con.close()
    
    print()
    print("✓ Todas as tabelas prontas!")
# Out:
# A criar 5 tabela(s)...
#
#   ✓ Tabela inform_27_0000 criada (ou já existia).
#   ✓ Tabela inform_27_2023 criada (ou já existia).
#   ✓ Tabela inform_27_2024 criada (ou já existia).
#   ✓ Tabela inform_27_2025 criada (ou já existia).
#   ✓ Tabela inform_27_2026 criada (ou já existia).
#
# ✓ Todas as tabelas prontas!

# %%
# ==============================================================================
# CONFIRMAR: Listar tabelas criadas
# ==============================================================================

con = sqlite3.connect(DB_PATH)
cur = con.cursor()

cur.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name")
tabelas_bd = [nome for (nome,) in cur.fetchall()]

print("Tabelas na BD:")
for tabela in tabelas_bd:
    print(f"  - {tabela}")

print()
for ano in anos_detectados:
    tabela_nome = f"inform_27_{ano}"
    cur.execute(f"PRAGMA table_info({tabela_nome})")
    colunas = cur.fetchall()
    print(f"Colunas de {tabela_nome}: {len(colunas)}")

con.close()
print()
print("✓ Estrutura confirmada!")
# Out:
# Tabelas na BD:
#   - cargas_2023
#   - cargas_2024
#   - cargas_2025
#   - cargas_2026
#   - entregas_2025
#   - entregas_2026
#   - inform_26_2024
#   - inform_26_2025
#   - inform_26_2026
#   - inform_27_0000
#   - inform_27_2023
#   - inform_27_2024
#   - inform_27_2025
#   - inform_27_2026
#   - km_diario_2023
#   - km_diario_2024
#   - km_diario_2025
#   - km_diario_2026
#   - sqlite_sequence
#
# Colunas de inform_27_0000: 58
# Colunas de inform_27_2023: 58
# Colunas de inform_27_2024: 58
# Colunas de inform_27_2025: 58
# Colunas de inform_27_2026: 58
#
# ✓ Estrutura confirmada!

# %% [markdown]
# ## PASSO 4 — Inserir Dados Dinamicamente

# %%
# ==============================================================================
# PREPARAR INSTRUÇÕES SQL (INSERT OR IGNORE) PARA CADA ANO
# ==============================================================================

cols_sql = ", ".join(f'"{c}"' for c in COLUNAS_FICHEIRO)
placeholders = ", ".join(["?"] * len(COLUNAS_FICHEIRO))
idx_data = COLUNAS_FICHEIRO.index(CAMPO_DATA)

# Gerar SQL para cada ano
sql_por_ano = {}
for ano in anos_detectados:
    tabela_nome = f"inform_27_{ano}"
    sql = f'INSERT OR IGNORE INTO {tabela_nome} ({cols_sql}, "{COLUNA_ORIGEM}") VALUES ({placeholders}, ?)'
    sql_por_ano[ano] = sql

print(f"✓ Instruções SQL geradas para {len(sql_por_ano)} ano(s):")
for ano in sorted(sql_por_ano.keys()):
    print(f"  - inform_27_{ano}")
# Out:
# ✓ Instruções SQL geradas para 5 ano(s):
#   - inform_27_0000
#   - inform_27_2023
#   - inform_27_2024
#   - inform_27_2025
#   - inform_27_2026

# %%
# ==============================================================================
# CRIAR ÍNDICES ÚNICOS (evita duplicatas)
# ==============================================================================

print("A criar índices únicos em CODEDT...")
print()

con = sqlite3.connect(DB_PATH)
cur = con.cursor()

for ano in anos_detectados:
    tabela_nome = f"inform_27_{ano}"
    indice_nome = f"idx_{tabela_nome}_codedt"
    try:
        cur.execute(f'''
            CREATE UNIQUE INDEX IF NOT EXISTS {indice_nome}
            ON {tabela_nome}("CODEDT")
        ''')
        print(f"  ✓ Índice {indice_nome} pronto.")
    except sqlite3.OperationalError:
        print(f"  ✓ Índice {indice_nome} já existia.")

con.commit()
con.close()
print()
print("✓ Índices criados!")
# Out:
# A criar índices únicos em CODEDT...
#
#   ✓ Índice idx_inform_27_0000_codedt pronto.
#   ✓ Índice idx_inform_27_2023_codedt pronto.
#   ✓ Índice idx_inform_27_2024_codedt pronto.
#   ✓ Índice idx_inform_27_2025_codedt pronto.
#   ✓ Índice idx_inform_27_2026_codedt pronto.
#
# ✓ Índices criados!

# %%
# ==============================================================================
# LISTAR FICHEIROS A PROCESSAR
# ==============================================================================

ficheiros = listar_ficheiros_excel(PASTA_FICHEIROS)

print(f"Ficheiros .xls encontrados: {len(ficheiros)}")
print()
for i, f in enumerate(ficheiros[:20], 1):
    print(f"  {i}. {os.path.basename(f)}")

if len(ficheiros) > 20:
    print(f"  ... e mais {len(ficheiros) - 20} ficheiro(s)")

print()
if not ficheiros:
    print("[AVISO] Nenhum ficheiro .xls encontrado. Verifica:")
    print(f"  - PASTA_FICHEIROS: {PASTA_FICHEIROS}")
    print(f"  - Se os ficheiros têm extensão .xls")
# Out:
# Ficheiros .xls encontrados: 72
#
#   1. SAL_DAT027 (1)-fev.xls
#   2. SAL_DAT027 (1)_julho.xls
#   3. SAL_DAT027 (11).xls
#   4. SAL_DAT027 (12).xls
#   5. SAL_DAT027 (13).xls
#   6. SAL_DAT027 (14).xls
#   7. SAL_DAT027 (15).xls
#   8. SAL_DAT027 (16).xls
#   9. SAL_DAT027 (17).xls
#   10. SAL_DAT027 (18).xls
#   11. SAL_DAT027 (19)-.xls
#   12. SAL_DAT027 (19).xls
#   13. SAL_DAT027 (2)_fev.xls
#   14. SAL_DAT027 (20)-.xls
#   15. SAL_DAT027 (20).xls
#   16. SAL_DAT027 (21)-.xls
#   17. SAL_DAT027 (21).xls
#   18. SAL_DAT027 (22)-.xls
#   19. SAL_DAT027 (22).xls
#   20. SAL_DAT027 (23)-.xls
#   ... e mais 52 ficheiro(s)

# %%
# ==============================================================================
# LOOP PRINCIPAL: Ler e inserir dados
# ==============================================================================

if not ficheiros:
    print("[ERRO] Sem ficheiros para processar.")
else:
    print("=" * 70)
    print("A PROCESSAR FICHEIROS")
    print("=" * 70)
    print()

    con = sqlite3.connect(DB_PATH)
    cur = con.cursor()

    # Dicionários para contar inserções
    totais_inseridos = {ano: 0 for ano in anos_detectados}
    totais_duplicados = 0
    totais_sem_data = 0

    for i, caminho in enumerate(ficheiros, start=1):
        nome_ficheiro = os.path.basename(caminho)
        print(f"[{i}/{len(ficheiros)}] A processar: {nome_ficheiro}")

        cabecalho, linhas = ler_linhas_xml_spreadsheet(caminho)
        if cabecalho is None:
            print(f"  [ERRO] Falha a ler o ficheiro. A saltar.")
            continue

        if CAMPO_DATA not in cabecalho:
            print(f"  [AVISO] Coluna '{CAMPO_DATA}' não encontrada. A saltar.")
            continue

        # Organizar linhas por ano
        batches_por_ano = {ano: [] for ano in anos_detectados}
        sem_data = 0

        for valores in linhas:
            # Ignorar linhas vazias
            if all(v is None or str(v).strip() == "" for v in valores):
                continue

            # Remapaer para ordem fixa
            mapa = dict(zip(cabecalho, valores))
            valores_ordenados = [mapa.get(c) for c in COLUNAS_FICHEIRO]

            # Extrair e validar data
            valor_data = valores_ordenados[idx_data]
            if not valor_data or not str(valor_data).strip()[:4].isdigit():
                sem_data += 1
                continue

            texto_data = str(valor_data).strip()
            ano = texto_data[:4]

            # Adicionar ao batch do ano correspondente
            if ano in batches_por_ano:
                batches_por_ano[ano].append(valores_ordenados + [nome_ficheiro])
            else:
                sem_data += 1

        # Inserir batches
        for ano in anos_detectados:
            batch = batches_por_ano[ano]
            if not batch:
                continue

            antes = con.total_changes
            cur.executemany(sql_por_ano[ano], batch)
            con.commit()
            inseridos = con.total_changes - antes
            totais_inseridos[ano] += inseridos

            # Contar duplicatas
            duplicados_neste_ano = len(batch) - inseridos
            totais_duplicados += duplicados_neste_ano

        totais_sem_data += sem_data

        # Resumo desta linha
        resumo = ", ".join(f"{totais_inseridos[a]} novo(s) em {a}" for a in sorted(anos_detectados))
        print(f"  -> {resumo}")
        print(f"     {totais_duplicados} duplicata(s), {totais_sem_data} sem data")
        print()

    con.close()

    # Resumo final
    print("=" * 70)
    print("RESUMO FINAL")
    print("=" * 70)
    print()
    print(f"Ficheiros processados: {len(ficheiros)}")
    print()
    for ano in sorted(anos_detectados):
        print(f"  Linhas novas inseridas em {ano}: {totais_inseridos[ano]:,}")
    print()
    print(f"Linhas já existentes (duplicadas por CODEDT): {totais_duplicados:,}")
    print(f"Linhas sem FENTREGA válido: {totais_sem_data:,}")
    print("=" * 70)
    print()
    print("✓ Inserção de dados concluída!")
# Out:
# ======================================================================
# A PROCESSAR FICHEIROS
# ======================================================================
#
# [1/72] A processar: SAL_DAT027 (1)-fev.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 0 novo(s) em 2026
#      7490 duplicata(s), 1 sem data
#
# [2/72] A processar: SAL_DAT027 (1)_julho.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      18036 duplicata(s), 2 sem data
#
# [3/72] A processar: SAL_DAT027 (11).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      24406 duplicata(s), 3 sem data
#
# [4/72] A processar: SAL_DAT027 (12).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      32135 duplicata(s), 4 sem data
#
# [5/72] A processar: SAL_DAT027 (13).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      32135 duplicata(s), 5 sem data
#
# [6/72] A processar: SAL_DAT027 (14).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      38448 duplicata(s), 6 sem data
#
# [7/72] A processar: SAL_DAT027 (15).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      46550 duplicata(s), 7 sem data
#
# [8/72] A processar: SAL_DAT027 (16).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      55745 duplicata(s), 8 sem data
#
# [9/72] A processar: SAL_DAT027 (17).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      55745 duplicata(s), 9 sem data
#
# [10/72] A processar: SAL_DAT027 (18).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      62889 duplicata(s), 10 sem data
#
# [11/72] A processar: SAL_DAT027 (19)-.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      62901 duplicata(s), 11 sem data
#
# [12/72] A processar: SAL_DAT027 (19).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      62901 duplicata(s), 12 sem data
#
# [13/72] A processar: SAL_DAT027 (2)_fev.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      71965 duplicata(s), 13 sem data
#
# [14/72] A processar: SAL_DAT027 (20)-.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      71965 duplicata(s), 14 sem data
#
# [15/72] A processar: SAL_DAT027 (20).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      78611 duplicata(s), 15 sem data
#
# [16/72] A processar: SAL_DAT027 (21)-.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      78618 duplicata(s), 16 sem data
#
# [17/72] A processar: SAL_DAT027 (21).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      86994 duplicata(s), 17 sem data
#
# [18/72] A processar: SAL_DAT027 (22)-.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      87000 duplicata(s), 18 sem data
#
# [19/72] A processar: SAL_DAT027 (22).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      87001 duplicata(s), 19 sem data
#
# [20/72] A processar: SAL_DAT027 (23)-.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      147361 duplicata(s), 20 sem data
#
# [21/72] A processar: SAL_DAT027 (23).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      154479 duplicata(s), 21 sem data
#
# [22/72] A processar: SAL_DAT027 (24)-.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      200786 duplicata(s), 22 sem data
#
# [23/72] A processar: SAL_DAT027 (24).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      210060 duplicata(s), 23 sem data
#
# [24/72] A processar: SAL_DAT027 (25)-.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      210070 duplicata(s), 24 sem data
#
# [25/72] A processar: SAL_DAT027 (25).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      210070 duplicata(s), 25 sem data
#
# [26/72] A processar: SAL_DAT027 (26)-.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      268841 duplicata(s), 26 sem data
#
# [27/72] A processar: SAL_DAT027 (26).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      275914 duplicata(s), 27 sem data
#
# [28/72] A processar: SAL_DAT027 (27)-.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      324092 duplicata(s), 28 sem data
#
# [29/72] A processar: SAL_DAT027 (27).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      333349 duplicata(s), 29 sem data
#
# [30/72] A processar: SAL_DAT027 (28)-.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      333351 duplicata(s), 30 sem data
#
# [31/72] A processar: SAL_DAT027 (28).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      333351 duplicata(s), 31 sem data
#
# [32/72] A processar: SAL_DAT027 (29)-.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      394394 duplicata(s), 32 sem data
#
# [33/72] A processar: SAL_DAT027 (29).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      404851 duplicata(s), 33 sem data
#
# [34/72] A processar: SAL_DAT027 (30)-.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      470385 duplicata(s), 33 sem data
#
# [35/72] A processar: SAL_DAT027 (30).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      477851 duplicata(s), 34 sem data
#
# [36/72] A processar: SAL_DAT027 (31).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      477852 duplicata(s), 35 sem data
#
# [37/72] A processar: SAL_DAT027 (32).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      487717 duplicata(s), 36 sem data
#
# [38/72] A processar: SAL_DAT027 (33).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      495430 duplicata(s), 37 sem data
#
# [39/72] A processar: SAL_DAT027 (34).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      495435 duplicata(s), 38 sem data
#
# [40/72] A processar: SAL_DAT027 (35).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      505492 duplicata(s), 39 sem data
#
# [41/72] A processar: SAL_DAT027 (36).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      513431 duplicata(s), 40 sem data
#
# [42/72] A processar: SAL_DAT027 (37).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      513431 duplicata(s), 41 sem data
#
# [43/72] A processar: SAL_DAT027 (38).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      521875 duplicata(s), 42 sem data
#
# [44/72] A processar: SAL_DAT027 (39).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      529317 duplicata(s), 43 sem data
#
# [45/72] A processar: SAL_DAT027 (40).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      529319 duplicata(s), 44 sem data
#
# [46/72] A processar: SAL_DAT027 (41).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      537274 duplicata(s), 45 sem data
#
# [47/72] A processar: SAL_DAT027 (42).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      545192 duplicata(s), 46 sem data
#
# [48/72] A processar: SAL_DAT027 (43).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      545194 duplicata(s), 47 sem data
#
# [49/72] A processar: SAL_DAT027 (44).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      552481 duplicata(s), 48 sem data
#
# [50/72] A processar: SAL_DAT027 (45).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      560437 duplicata(s), 49 sem data
#
# [51/72] A processar: SAL_DAT027 (46).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      560442 duplicata(s), 50 sem data
#
# [52/72] A processar: SAL_DAT027 (47).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      569232 duplicata(s), 51 sem data
#
# [53/72] A processar: SAL_DAT027 (48).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      578432 duplicata(s), 52 sem data
#
# [54/72] A processar: SAL_DAT027 (49).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      578432 duplicata(s), 53 sem data
#
# [55/72] A processar: SAL_DAT027 (50).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      586365 duplicata(s), 54 sem data
#
# [56/72] A processar: SAL_DAT027 (51).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      594215 duplicata(s), 55 sem data
#
# [57/72] A processar: SAL_DAT027 (52).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      594217 duplicata(s), 56 sem data
#
# [58/72] A processar: SAL_DAT027 (53).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      603130 duplicata(s), 57 sem data
#
# [59/72] A processar: SAL_DAT027 (54).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      610083 duplicata(s), 58 sem data
#
# [60/72] A processar: SAL_DAT027 (55).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      610221 duplicata(s), 59 sem data
#
# [61/72] A processar: SAL_DAT027 (56).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      618005 duplicata(s), 60 sem data
#
# [62/72] A processar: SAL_DAT027 (57).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      626672 duplicata(s), 61 sem data
#
# [63/72] A processar: SAL_DAT027 (58).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      626834 duplicata(s), 62 sem data
#
# [64/72] A processar: SAL_DAT027 (59).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      633510 duplicata(s), 63 sem data
#
# [65/72] A processar: SAL_DAT027 (60).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      641786 duplicata(s), 64 sem data
#
# [66/72] A processar: SAL_DAT027 (61).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      641799 duplicata(s), 65 sem data
#
# [67/72] A processar: SAL_DAT027 (62).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      648047 duplicata(s), 66 sem data
#
# [68/72] A processar: SAL_DAT027 (63).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      655826 duplicata(s), 67 sem data
#
# [69/72] A processar: SAL_DAT027 (9).xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      655827 duplicata(s), 68 sem data
#
# [70/72] A processar: SAL_DAT027-fev.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      655829 duplicata(s), 69 sem data
#
# [71/72] A processar: SAL_DAT027_julho.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 4793 novo(s) em 2026
#      655829 duplicata(s), 70 sem data
#
# [72/72] A processar: SAL_DAT027_julho_2.xls
#   -> 0 novo(s) em 0000, 0 novo(s) em 2023, 0 novo(s) em 2024, 0 novo(s) em 2025, 11109 novo(s) em 2026
#      669606 duplicata(s), 71 sem data
#
# ======================================================================
# RESUMO FINAL
# ======================================================================
#
# Ficheiros processados: 72
#
#   Linhas novas inseridas em 0000: 0
#   Linhas novas inseridas em 2023: 0
#   Linhas novas inseridas em 2024: 0
#   Linhas novas inseridas em 2025: 0
#   Linhas novas inseridas em 2026: 11,109
#
# Linhas já existentes (duplicadas por CODEDT): 669,606
# Linhas sem FENTREGA válido: 71
# ======================================================================
#
# ✓ Inserção de dados concluída!

# %% [markdown]
# ## PASSO 5 — Inspecionar a Base de Dados

# %%
# ==============================================================================
# ESTATÍSTICAS POR TABELA/ANO
# ==============================================================================

print("=" * 70)
print("INSPEÇÃO DA BASE DE DADOS")
print("=" * 70)
print()

con = sqlite3.connect(DB_PATH)
con.row_factory = sqlite3.Row
cur = con.cursor()

# Detectar tabelas de dados
anos_na_bd = detectar_anos_na_bd(DB_PATH)

print(f"Anos com tabelas na BD: {', '.join(anos_na_bd)}")
print()

total_geral = 0
for ano in anos_na_bd:
    tabela = f"inform_27_{ano}"
    
    # Contar registos
    cur.execute(f"SELECT COUNT(*) FROM {tabela}")
    count = cur.fetchone()[0]
    total_geral += count
    
    # Contar ficheiros únicos
    cur.execute(f"SELECT COUNT(DISTINCT ficheiro_origem) FROM {tabela}")
    num_ficheiros = cur.fetchone()[0]
    
    # Data mais antiga e recente
    cur.execute(f"SELECT MIN(FENTREGA), MAX(FENTREGA) FROM {tabela}")
    row = cur.fetchone()
    data_min = row[0] if row[0] else "N/A"
    data_max = row[1] if row[1] else "N/A"
    
    # Contar CODEDTs únicos
    cur.execute(f"SELECT COUNT(DISTINCT CODEDT) FROM {tabela}")
    codedt_unicos = cur.fetchone()[0]
    
    print(f"📊 inform-27_{ano}:")
    print(f"   • Registos totais: {count:,}")
    print(f"   • CODEDT únicos: {codedt_unicos:,}")
    print(f"   • Ficheiros importados: {num_ficheiros}")
    print(f"   • Data mais antiga: {data_min}")
    print(f"   • Data mais recente: {data_max}")
    print()

print(f"📈 TOTAL DE REGISTOS NA BD: {total_geral:,}")
print()

con.close()
# Out:
# ======================================================================
# INSPEÇÃO DA BASE DE DADOS
# ======================================================================
#
# Anos com tabelas na BD: 0000, 2023, 2024, 2025, 2026
#
# 📊 inform-27_0000:
#    • Registos totais: 10
#    • CODEDT únicos: 10
#    • Ficheiros importados: 2
#    • Data mais antiga: 00000000
#    • Data mais recente: 00000000
#
# 📊 inform-27_2023:
#    • Registos totais: 106,399
#    • CODEDT únicos: 106,399
#    • Ficheiros importados: 7
#    • Data mais antiga: 20230516
#    • Data mais recente: 20231231
#
# 📊 inform-27_2024:
#    • Registos totais: 186,335
#    • CODEDT únicos: 186,335
#    • Ficheiros importados: 9
#    • Data mais antiga: 20240102
#    • Data mais recente: 20241231
#
# 📊 inform-27_2025:
#    • Registos totais: 190,938
#    • CODEDT únicos: 190,938
#    • Ficheiros importados: 35
#    • Data mais antiga: 20250102
#    • Data mais recente: 20251231
#
# 📊 inform-27_2026:
#    • Registos totais: 108,219
#    • CODEDT únicos: 108,219
#    • Ficheiros importados: 21
#    • Data mais antiga: 20260102
#    • Data mais recente: 20260810
#
# 📈 TOTAL DE REGISTOS NA BD: 591,901

# %%
# ==============================================================================
# FICHEIROS IMPORTADOS (POR TABELA)
# ==============================================================================

print("=" * 70)
print("FICHEIROS IMPORTADOS")
print("=" * 70)
print()

con = sqlite3.connect(DB_PATH)
cur = con.cursor()

for ano in anos_na_bd:
    tabela = f"inform_27_{ano}"
    cur.execute(f"SELECT DISTINCT ficheiro_origem, COUNT(*) FROM {tabela} "
                f"GROUP BY ficheiro_origem ORDER BY COUNT(*) DESC")
    ficheiros_result = cur.fetchall()
    
    if ficheiros_result:
        print(f"📁 inform_27_{ano}:")
        for ficheiro, count in ficheiros_result:
            print(f"   • {ficheiro}: {count:,} linhas")
    else:
        print(f"📁 inform_27_{ano}: (vazio)")
    print()

con.close()
# Out:
# ======================================================================
# FICHEIROS IMPORTADOS
# ======================================================================
#
# 📁 inform_27_0000:
#    • SAL_DAT027 (27)-.xls: 6 linhas
#    • SAL_DAT027 (26)-.xls: 4 linhas
#
# 📁 inform_27_2023:
#    • SAL_DAT027 (23)-.xls: 60,283 linhas
#    • SAL_DAT027 (24)-.xls: 46,080 linhas
#    • SAL_DAT027 (19)-.xls: 12 linhas
#    • SAL_DAT027 (26)-.xls: 8 linhas
#    • SAL_DAT027 (21)-.xls: 7 linhas
#    • SAL_DAT027 (22)-.xls: 6 linhas
#    • SAL_DAT027 (27)-.xls: 3 linhas
#
# 📁 inform_27_2024:
#    • SAL_DAT027 (29)-.xls: 60,394 linhas
#    • SAL_DAT027 (26)-.xls: 58,759 linhas
#    • SAL_DAT027 (27)-.xls: 48,169 linhas
#    • SAL_DAT027 (30)-.xls: 18,694 linhas
#    • SAL_DAT027 (24)-.xls: 227 linhas
#    • SAL_DAT027 (23)-.xls: 77 linhas
#    • SAL_DAT027 (25)-.xls: 10 linhas
#    • SAL_DAT027 (29).xls: 3 linhas
#    • SAL_DAT027 (28)-.xls: 2 linhas
#
# 📁 inform_27_2025:
#    • SAL_DAT027 (29).xls: 10,454 linhas
#    • SAL_DAT027 (35).xls: 9,947 linhas
#    • SAL_DAT027 (32).xls: 9,751 linhas
#    • SAL_DAT027 (48).xls: 8,787 linhas
#    • SAL_DAT027 (53).xls: 8,538 linhas
#    • SAL_DAT027 (47).xls: 8,409 linhas
#    • SAL_DAT027 (57).xls: 8,388 linhas
#    • SAL_DAT027 (60).xls: 8,268 linhas
#    • SAL_DAT027 (38).xls: 7,950 linhas
#    • SAL_DAT027 (45).xls: 7,946 linhas
#    • SAL_DAT027 (36).xls: 7,906 linhas
#    • SAL_DAT027 (42).xls: 7,858 linhas
#    • SAL_DAT027 (41).xls: 7,797 linhas
#    • SAL_DAT027 (50).xls: 7,668 linhas
#    • SAL_DAT027 (33).xls: 7,659 linhas
#    • SAL_DAT027 (51).xls: 7,487 linhas
#    • SAL_DAT027 (63).xls: 7,466 linhas
#    • SAL_DAT027 (30).xls: 7,466 linhas
#    • SAL_DAT027 (56).xls: 7,424 linhas
#    • SAL_DAT027 (44).xls: 7,191 linhas
#    • SAL_DAT027 (39).xls: 6,900 linhas
#    • SAL_DAT027 (59).xls: 6,667 linhas
#    • SAL_DAT027 (54).xls: 6,529 linhas
#    • SAL_DAT027 (62).xls: 5,860 linhas
#    • SAL_DAT027 (29)-.xls: 276 linhas
#    • SAL_DAT027 (58).xls: 162 linhas
#    • SAL_DAT027 (55).xls: 138 linhas
#    • SAL_DAT027 (11).xls: 16 linhas
#    • SAL_DAT027 (61).xls: 13 linhas
#    • SAL_DAT027 (46).xls: 5 linhas
#    • SAL_DAT027 (34).xls: 5 linhas
#    • SAL_DAT027 (52).xls: 2 linhas
#    • SAL_DAT027 (43).xls: 2 linhas
#    • SAL_DAT027 (40).xls: 2 linhas
#    • SAL_DAT027 (31).xls: 1 linhas
#
# 📁 inform_27_2026:
#    • SAL_DAT027 (24).xls: 9,211 linhas
#    • SAL_DAT027 (16).xls: 9,195 linhas
#    • SAL_DAT027 (15).xls: 8,102 linhas
#    • SAL_DAT027 (12).xls: 7,729 linhas
#    • SAL_DAT027 (21).xls: 7,628 linhas
#    • SAL_DAT027 (2)_fev.xls: 7,389 linhas
#    • SAL_DAT027 (18).xls: 7,144 linhas
#    • SAL_DAT027 (23).xls: 6,983 linhas
#    • SAL_DAT027 (11).xls: 6,354 linhas
#    • SAL_DAT027_julho_2.xls: 6,316 linhas
#    • SAL_DAT027 (14).xls: 6,313 linhas
#    • SAL_DAT027 (20).xls: 6,130 linhas
#    • SAL_DAT027 (1)-fev.xls: 6,109 linhas
#    • SAL_DAT027 (1)_julho.xls: 4,793 linhas
#    • SAL_DAT027 (27).xls: 4,758 linhas
#    • SAL_DAT027 (26).xls: 3,645 linhas
#    • SAL_DAT027 (63).xls: 231 linhas
#    • SAL_DAT027 (62).xls: 185 linhas
#    • SAL_DAT027-fev.xls: 2 linhas
#    • SAL_DAT027 (9).xls: 1 linhas
#    • SAL_DAT027 (22).xls: 1 linhas

# %% [markdown]
# ## PASSO 6 — Ferramentas Interativas de Consulta

# %%
# ==============================================================================
# FERRAMENTA 1: Buscar por CODEDT
# ==============================================================================

def buscar_por_codedt(codedt_procura):
    """Procura um CODEDT em todas as tabelas."""
    con = sqlite3.connect(DB_PATH)
    con.row_factory = sqlite3.Row
    cur = con.cursor()
    
    anos_na_bd = detectar_anos_na_bd(DB_PATH)
    encontrados = False
    
    for ano in anos_na_bd:
        tabela = f"inform_27_{ano}"
        cur.execute(f"SELECT id, FENTREGA, TRANSPORTISTA, LOCORIGEN, "
                   f"LOCDESTINO, COBROREAL FROM {tabela} WHERE CODEDT = ?", (codedt_procura,))
        registos = cur.fetchall()
        
        if registos:
            encontrados = True
            print(f"✓ Encontrado em inform_27_{ano}:")
            for reg in registos:
                print(f"  ID: {reg['id']}, Data: {reg['FENTREGA']}, "
                      f"Transportista: {reg['TRANSPORTISTA']}")
                print(f"  Rota: {reg['LOCORIGEN']} → {reg['LOCDESTINO']}, "
                      f"Cobro: {reg['COBROREAL']}")
                print()
    
    con.close()
    
    if not encontrados:
        print(f"✗ CODEDT '{codedt_procura}' não encontrado em nenhuma tabela.")

# Exemplo: descomentar a linha abaixo para testar
# buscar_por_codedt("123456")

print("✓ Função buscar_por_codedt() pronta")
# Out:
# ✓ Função buscar_por_codedt() pronta

# %%
# ==============================================================================
# FERRAMENTA 2: Listar transportistas únicos
# ==============================================================================

def listar_transportistas(ano):
    """Lista transportistas únicos de um ano."""
    anos_na_bd = detectar_anos_na_bd(DB_PATH)
    
    if ano not in anos_na_bd:
        print(f"✗ Ano '{ano}' não existe. Anos disponíveis: {', '.join(anos_na_bd)}")
        return
    
    con = sqlite3.connect(DB_PATH)
    cur = con.cursor()
    
    tabela = f"inform_27_{ano}"
    cur.execute(f"SELECT DISTINCT TRANSPORTISTA FROM {tabela} "
               f"WHERE TRANSPORTISTA IS NOT NULL AND TRANSPORTISTA != '' "
               f"ORDER BY TRANSPORTISTA")
    transportistas = [row[0] for row in cur.fetchall()]
    
    con.close()
    
    print(f"✓ Transportistas únicos em {tabela}: {len(transportistas)}")
    print()
    for i, t in enumerate(transportistas[:20], 1):
        print(f"  {i}. {t}")
    if len(transportistas) > 20:
        print(f"  ... e mais {len(transportistas) - 20}")

# Exemplo: descomentar para testar
# listar_transportistas("2025")

print("✓ Função listar_transportistas() pronta")
# Out:
# ✓ Função listar_transportistas() pronta

# %%
# ==============================================================================
# FERRAMENTA 3: Top 10 locais de origem
# ==============================================================================

def top_locais_origem(ano):
    """Mostra os top 10 locais de origem de um ano."""
    anos_na_bd = detectar_anos_na_bd(DB_PATH)
    
    if ano not in anos_na_bd:
        print(f"✗ Ano '{ano}' não existe. Anos disponíveis: {', '.join(anos_na_bd)}")
        return
    
    con = sqlite3.connect(DB_PATH)
    cur = con.cursor()
    
    tabela = f"inform_27_{ano}"
    cur.execute(f"SELECT LOCORIGEN, COUNT(*) FROM {tabela} "
               f"WHERE LOCORIGEN IS NOT NULL AND LOCORIGEN != '' "
               f"GROUP BY LOCORIGEN ORDER BY COUNT(*) DESC LIMIT 10")
    registos = cur.fetchall()
    
    con.close()
    
    print(f"✓ Top 10 locais de origem em {tabela}:")
    print()
    for i, (localidade, count) in enumerate(registos, 1):
        print(f"  {i}. {localidade}: {count:,} registos")

# Exemplo: descomentar para testar
# top_locais_origem("2025")

print("✓ Função top_locais_origem() pronta")
# Out:
# ✓ Função top_locais_origem() pronta

# %% [markdown]
# ## 📝 Notas Finais

# %%
print("=" * 70)
print("✓ NOTEBOOK COMPLETO EXECUTADO COM SUCESSO!")
print("=" * 70)
print()
print("📊 O que foi feito:")
print("  1. Detectou automaticamente os anos nos ficheiros")
print("  2. Criou tabelas para TODOS os anos")
print("  3. Inseriu dados sem duplicatas")
print("  4. Mostrou estatísticas completas")
print()
print("🛠️  Ferramentas disponíveis:")
print("  • buscar_por_codedt(codedt) - Procurar por código")
print("  • listar_transportistas(ano) - Ver transportistas")
print("  • top_locais_origem(ano) - Ver top 10 locais")
print()
print("🚀 Próximos passos:")
print("  • Modifica as funções acima para fazer consultas personalizadas")
print("  • Se tiveres novos dados em 2027+, corre novamente o notebook")
print("  • Usa as funções para explorar os dados")
print()
print("=" * 70)
# Out:
# ======================================================================
# ✓ NOTEBOOK COMPLETO EXECUTADO COM SUCESSO!
# ======================================================================
#
# 📊 O que foi feito:
#   1. Detectou automaticamente os anos nos ficheiros
#   2. Criou tabelas para TODOS os anos
#   3. Inseriu dados sem duplicatas
#   4. Mostrou estatísticas completas
#
# 🛠️  Ferramentas disponíveis:
#   • buscar_por_codedt(codedt) - Procurar por código
#   • listar_transportistas(ano) - Ver transportistas
#   • top_locais_origem(ano) - Ver top 10 locais
#
# 🚀 Próximos passos:
#   • Modifica as funções acima para fazer consultas personalizadas
#   • Se tiveres novos dados em 2027+, corre novamente o notebook
#   • Usa as funções para explorar os dados
#
# ======================================================================
