# %%
import sqlite3
import pandas as pd
import platform
import warnings
warnings.filterwarnings('ignore')

# Detecção do SO e caminho BD
if platform.system() == 'Windows':
    DB_PATH = r"C:\Users\LISARR\Documents\python\00.DB\2026.db"
elif platform.system() == 'Darwin':
    DB_PATH = "/Volumes/RR/DB/inform_27.db"


caminho = r"C:\Users\LISARR\Documents\python\01.Financeiro\Danone_Custos_V2.xlsx"

# Conectar
con = sqlite3.connect(DB_PATH)
cursor = con.cursor()

# %%
df = pd.read_sql_query("SELECT * FROM inform_27_2026", con)
con.close()

# %%
print(f"Shape: {df.shape}")
print(f"\nColunas: {df.shape[1]}")
df.head()
# Out:
# Shape: (774239, 58)
#
# Colunas: 58
#    id PROPIETARIO                                        TRAYECTO  \
# 0   1         4PL  CARREFOUR BOLLENE / PLAT. CARREFOUR MIRALCAMPO
# 1   2         4PL  CARREFOUR BOLLENE / PLAT. CARREFOUR MIRALCAMPO
# 2   3         4PL  CARREFOUR BOLLENE / PLAT. CARREFOUR MIRALCAMPO
# 3   4         4PL  CARREFOUR BOLLENE / PLAT. CARREFOUR MIRALCAMPO
# 4   5         4PL  CARREFOUR BOLLENE / PLAT. CARREFOUR MIRALCAMPO
#
#                       TRANSPORTISTA  TRACTORA REMOLQUE INGRESODT COSTEDT  \
# 0  CENTROTIR LOGISTIC SERVICES S.A.  3131-MST  0000XXX         0       0
# 1  CENTROTIR LOGISTIC SERVICES S.A.  3131-MST  0000XXX         0       0
# 2  CENTROTIR LOGISTIC SERVICES S.A.  3131-MST  0000XXX         0       0
# 3  CENTROTIR LOGISTIC SERVICES S.A.  3131-MST  0000XXX         0       0
# 4  CENTROTIR LOGISTIC SERVICES S.A.  3131-MST  0000XXX         0       0
#
#   RENTADT PALETSDT  ...  LOCDES               LUGARDESCARGA TEMP_MERC_PED  \
# 0       0     0.11  ...  297643  PLAT. CARREFOUR MIRALCAMPO           RFG
# 1       0      0.4  ...  297643  PLAT. CARREFOUR MIRALCAMPO           RFG
# 2       0        1  ...  297643  PLAT. CARREFOUR MIRALCAMPO           RFG
# 3       0        1  ...  297643  PLAT. CARREFOUR MIRALCAMPO           RFG
# 4       0     1.02  ...  297643  PLAT. CARREFOUR MIRALCAMPO           RFG
#
#   TIPOPALETA      CAMION_TIPO CAMION_CAPACIDAD TIPO_COMBUSTIBLE  KMREALES  \
# 0        EUR  Trailer 33 plts               33           DIESEL  1014.971
# 1        EUR  Trailer 33 plts               33           DIESEL  1014.971
# 2        EUR  Trailer 33 plts               33           DIESEL  1014.971
# 3        EUR  Trailer 33 plts               33           DIESEL  1014.971
# 4        EUR  Trailer 33 plts               33           DIESEL  1014.971
#
#   ALBARAN     ficheiro_origem
# 0      NO  SAL_DAT027 (1).xls
# 1      NO  SAL_DAT027 (1).xls
# 2      NO  SAL_DAT027 (1).xls
# 3      NO  SAL_DAT027 (1).xls
# 4      NO  SAL_DAT027 (1).xls
#
# [5 rows x 58 columns]

# %%
# Converter tipos de dados numéricos
df['INGRESODT'] = pd.to_numeric(df['INGRESODT'], errors='coerce')
df['COSTEDT'] = pd.to_numeric(df['COSTEDT'], errors='coerce')
df['RENTADT'] = pd.to_numeric(df['RENTADT'], errors='coerce')
df['PALETSDT'] = pd.to_numeric(df['PALETSDT'], errors='coerce')
df['PESO_BRUTO'] = pd.to_numeric(df['PESO_BRUTO'], errors='coerce')
df['PALETS'] = pd.to_numeric(df['PALETS'], errors='coerce')
df['KM'] = pd.to_numeric(df['KM'], errors='coerce')
df['KMREALES'] = pd.to_numeric(df['KMREALES'], errors='coerce')

# CODEUT como string
df['CODEUT'] = df['CODEUT'].astype(str)

# Trim em strings (ANTES de converter as datas)
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# Datas como datetime (sem hora, prontas para PBI) - DEPOIS do trim
df['FCARGA'] = pd.to_datetime(df['FCARGA'], format='%Y%m%d', errors='coerce').dt.date
df['FENTREGA'] = pd.to_datetime(df['FENTREGA'], format='%Y%m%d', errors='coerce').dt.date

# %%
print(f"Shape: {df.shape}")
print(f"\nTipos de dados:")
print(df.dtypes)
print(f"\nNulos por coluna:")
print(df.isnull().sum())
df.head()
# Out:
# Shape: (774239, 58)
#
# Tipos de dados:
# id                    int64
# PROPIETARIO             str
# TRAYECTO                str
# TRANSPORTISTA           str
# TRACTORA                str
# REMOLQUE                str
# INGRESODT           float64
# COSTEDT             float64
# RENTADT             float64
# PALETSDT            float64
# PESO_BRUTO          float64
# CODEUT                  str
# ESTADO_UT               str
# RANGO_UT                str
# FCARGA               object
# ACTIVIDAD               str
# CODEDT                  str
# ESTADO_DT               str
# REFERENCIA              str
# CODACT                  str
# LOCORIGEN               str
# PROV_ORIGEN             str
# PAISORIGEN              str
# CPOSTAL                 str
# LOCDESTINO              str
# PROV_DESTINO            str
# PAISDESTINO             str
# CPOSTAD                 str
# KM                  float64
# FENTREGA             object
# ORIGEN                  str
# ENTREGAR                str
# PROV_ENTREGAR           str
# PAISENTREGAR            str
# DESTINO                 str
# PALETS              float64
# PREFAC                  str
# RUTA                    str
# COBROREAL               str
# GESTION                 str
# DEPART                  str
# USCODE                  str
# USUARIO                 str
# TIPOCLIENTE             str
# TIPOFLUJO               str
# WMSCODRGT               str
# LOCCAR                  str
# LUGARCARGA              str
# LOCDES                  str
# LUGARDESCARGA           str
# TEMP_MERC_PED           str
# TIPOPALETA              str
# CAMION_TIPO             str
# CAMION_CAPACIDAD        str
# TIPO_COMBUSTIBLE        str
# KMREALES            float64
# ALBARAN                 str
# ficheiro_origem         str
# dtype: object
#
# Nulos por coluna:
# id                       0
# PROPIETARIO              0
# TRAYECTO             11652
# TRANSPORTISTA            0
# TRACTORA            265979
# REMOLQUE               711
# INGRESODT                0
# COSTEDT                  0
# RENTADT                  0
# PALETSDT                 0
# PESO_BRUTO               0
# CODEUT                   0
# ESTADO_UT                0
# RANGO_UT                 0
# FCARGA                 729
# ACTIVIDAD                0
# CODEDT                   0
# ESTADO_DT                0
# REFERENCIA               0
# CODACT                   0
# LOCORIGEN              713
# PROV_ORIGEN             69
# PAISORIGEN              25
# CPOSTAL                 25
# LOCDESTINO           19835
# PROV_DESTINO         16791
# PAISDESTINO             69
# CPOSTAD                 69
# KM                  163919
# FENTREGA                 0
# ORIGEN               12322
# ENTREGAR                91
# PROV_ENTREGAR        17135
# PAISENTREGAR            91
# DESTINO              15235
# PALETS                   0
# PREFAC                   0
# RUTA                     0
# COBROREAL                0
# GESTION              83123
# DEPART               83123
# USCODE               19609
# USUARIO              19609
# TIPOCLIENTE         294770
# TIPOFLUJO                0
# WMSCODRGT            60983
# LOCCAR                  25
# LUGARCARGA              25
# LOCDES                  69
# LUGARDESCARGA           69
# TEMP_MERC_PED         5403
# TIPOPALETA               0
# CAMION_TIPO            676
# CAMION_CAPACIDAD         0
# TIPO_COMBUSTIBLE      3796
# KMREALES                 0
# ALBARAN                  0
# ficheiro_origem          0
# dtype: int64
#    id PROPIETARIO                                        TRAYECTO  \
# 0   1         4PL  CARREFOUR BOLLENE / PLAT. CARREFOUR MIRALCAMPO
# 1   2         4PL  CARREFOUR BOLLENE / PLAT. CARREFOUR MIRALCAMPO
# 2   3         4PL  CARREFOUR BOLLENE / PLAT. CARREFOUR MIRALCAMPO
# 3   4         4PL  CARREFOUR BOLLENE / PLAT. CARREFOUR MIRALCAMPO
# 4   5         4PL  CARREFOUR BOLLENE / PLAT. CARREFOUR MIRALCAMPO
#
#                       TRANSPORTISTA  TRACTORA REMOLQUE  INGRESODT  COSTEDT  \
# 0  CENTROTIR LOGISTIC SERVICES S.A.  3131-MST  0000XXX        0.0      0.0
# 1  CENTROTIR LOGISTIC SERVICES S.A.  3131-MST  0000XXX        0.0      0.0
# 2  CENTROTIR LOGISTIC SERVICES S.A.  3131-MST  0000XXX        0.0      0.0
# 3  CENTROTIR LOGISTIC SERVICES S.A.  3131-MST  0000XXX        0.0      0.0
# 4  CENTROTIR LOGISTIC SERVICES S.A.  3131-MST  0000XXX        0.0      0.0
#
#    RENTADT  PALETSDT  ...  LOCDES               LUGARDESCARGA TEMP_MERC_PED  \
# 0      0.0      0.11  ...  297643  PLAT. CARREFOUR MIRALCAMPO           RFG
# 1      0.0      0.40  ...  297643  PLAT. CARREFOUR MIRALCAMPO           RFG
# 2      0.0      1.00  ...  297643  PLAT. CARREFOUR MIRALCAMPO           RFG
# 3      0.0      1.00  ...  297643  PLAT. CARREFOUR MIRALCAMPO           RFG
# 4      0.0      1.02  ...  297643  PLAT. CARREFOUR MIRALCAMPO           RFG
#
#   TIPOPALETA      CAMION_TIPO CAMION_CAPACIDAD TIPO_COMBUSTIBLE  KMREALES  \
# 0        EUR  Trailer 33 plts               33           DIESEL  1014.971
# 1        EUR  Trailer 33 plts               33           DIESEL  1014.971
# 2        EUR  Trailer 33 plts               33           DIESEL  1014.971
# 3        EUR  Trailer 33 plts               33           DIESEL  1014.971
# 4        EUR  Trailer 33 plts               33           DIESEL  1014.971
#
#   ALBARAN     ficheiro_origem
# 0      NO  SAL_DAT027 (1).xls
# 1      NO  SAL_DAT027 (1).xls
# 2      NO  SAL_DAT027 (1).xls
# 3      NO  SAL_DAT027 (1).xls
# 4      NO  SAL_DAT027 (1).xls
#
# [5 rows x 58 columns]

# %%
# Caminho do ficheiro


# Ler a dinâmica a partir da linha 7 (skiprows=6), até coluna N
df_danone = pd.read_excel(
    caminho,
    sheet_name="Ingreso_coste_RR",
    skiprows=6,  # Pula as primeiras 6 linhas para começar na linha 7
    usecols=range(14)  # Colunas A-N (0-13)
)

# Remover a última linha se for totais (verifica o padrão)
if df_danone.iloc[-1, 0] in ['Total', 'TOTAL', 'Totals']:
    df_danone = df_danone[:-1]

# Garantir tipos de dados apropriados onde necessário
df_danone = df_danone.reset_index(drop=True)

# %%
print(f"Removidas {(df_danone['CODEDT'].isna() | (df_danone['CODEDT'] == '(blank)')).sum()} linhas"); df_danone = df_danone[~((df_danone['CODEDT'].isna()) | (df_danone['CODEDT'] == '(blank)'))]
# Out:
# Removidas 2 linhas

# %%
df_danone.head(5)
# Out:
#      CODEDT   FENTREGA                REFERENCIA     CODEUT  PEDPESONETO  \
# 0  25392905 2026-01-02  5021755057     413962691  3347518.0         8.35
# 1  25392907 2026-01-02  5021735096     413969126  3347519.0         4.50
# 2  25392909 2026-01-02  5021755060     413965689  3347519.0         6.08
# 3  25392911 2026-01-02  5021721307     413942431  3347512.0        32.04
# 4  25393080 2026-01-06  5021741331     413966458  3346529.0         2.16
#
#                      LOCORIGEN                           LOCDESTINO  \
# 0                        CMTIR                         A.S. FRANCOS
# 1                        CMTIR                    A.S. SRA. DA HORA
# 2                        CMTIR  A.S. BOAVISTA - DISTRIBUIÇÃO NORMAL
# 3                        CMTIR           PLATAFORMA DO PORTO - 2101
# 4  SALVESEN LOGISTICA PORTUGAL            OFERTA PRODUTO -R.HUMANOS
#
#   PROV_DESTINO  Suma de COSTEDT  Sum of Ingreso  Resultado  \
# 0        Porto             4.04       30.843115  26.803115
# 1        Porto             0.50       30.843115  30.343115
# 2        Porto             0.50       30.843115  30.343115
# 3        Porto             4.68        0.909688  -3.770312
# 4       Lisboa             0.41        0.000000  -0.410000
#
#             Grupo tarifario  Month  Unnamed: 13
# 0                   Ofertas      1          NaN
# 1                   Ofertas      1          NaN
# 2                   Ofertas      1          NaN
# 3                 GS Centro      1          NaN
# 4  Sin Transporte Marketing      1          NaN

# %%
df_danone.tail(5)
# Out:
#          CODEDT   FENTREGA                REFERENCIA     CODEUT  PEDPESONETO  \
# 16486  26341867 2026-08-03  5023464149     415610847  3511658.0     36185.06
# 16487  26341871 2026-08-03  5023463416     415610851  3511653.0     33218.52
# 16488  26341872 2026-08-03  5023463416     415610851  3511655.0     33218.52
# 16489  26341879 2026-08-03  5023464149     415610847  3511656.0     36185.06
# 16490  26341882 2026-08-03  5023464149     415610847  3511657.0     36185.06
#
#                          LOCORIGEN                  LOCDESTINO PROV_DESTINO  \
# 16486  SALVESEN LOGISTICA PORTUGAL  MODELO CONTINENTE AZAMBUJA       Lisboa
# 16487  SALVESEN LOGISTICA PORTUGAL            PLAT. MODIS MAIA        Porto
# 16488  SALVESEN LOGISTICA PORTUGAL            PLAT. MODIS MAIA        Porto
# 16489  SALVESEN LOGISTICA PORTUGAL  MODELO CONTINENTE AZAMBUJA       Lisboa
# 16490  SALVESEN LOGISTICA PORTUGAL  MODELO CONTINENTE AZAMBUJA       Lisboa
#
#        Suma de COSTEDT  Sum of Ingreso    Resultado Grupo tarifario  Month  \
# 16486            80.14      512.357415   432.217415      Azambuja 1      8
# 16487             0.00     1031.214611  1031.214611         Norte 1      8
# 16488             0.00     1031.214611  1031.214611         Norte 1      8
# 16489             0.00      512.357415   512.357415      Azambuja 1      8
# 16490             0.00      512.357415   512.357415      Azambuja 1      8
#
#        Unnamed: 13
# 16486          NaN
# 16487          NaN
# 16488          NaN
# 16489          NaN
# 16490          NaN

# %%
# Preparar df_danone - remover coluna vazia e selecionar as necessárias
df_danone = df_danone[['CODEDT', 'REFERENCIA', 'CODEUT', 'Sum of Ingreso']].copy()
df_danone.columns = ['CODEDT', 'REFERENCIA', 'CODEUT', 'Ingreso']

# Converter tipos de dados
df_danone['CODEDT'] = pd.to_numeric(df_danone['CODEDT'], errors='coerce').fillna(0).astype('Int64')
df_danone['CODEUT'] = df_danone['CODEUT'].astype('Int64').astype(str)
df_danone['CODEUT'] = df_danone['CODEUT'].astype(str).str.strip()
df_danone['REFERENCIA'] = df_danone['REFERENCIA'].astype(str).str.strip()
df_danone['Ingreso'] = pd.to_numeric(df_danone['Ingreso'], errors='coerce')

# Limpeza de espaços no df
df['REFERENCIA'] = df['REFERENCIA'].astype(str).str.strip()
df['CODEUT'] = df['CODEUT'].astype(str).str.strip()
df['CODEDT'] = pd.to_numeric(df['CODEDT'], errors='coerce').fillna(0).astype('Int64')

# Função de lookup otimizada com merge
def buscar_ingreso_danone(row):
    codeut = str(row['CODEUT']).strip()
    referencia = str(row['REFERENCIA']).strip()
    codedt = int(row['CODEDT']) if pd.notna(row['CODEDT']) else None
    
    # Tentativa 1: CODEUT + REFERENCIA
    match1 = df_danone[(df_danone['CODEUT'] == codeut) & (df_danone['REFERENCIA'] == referencia)]
    if not match1.empty:
        return match1['Ingreso'].iloc[0]
    
    # Tentativa 2: CODEUT + CODEDT
    if codedt is not None:
        match2 = df_danone[(df_danone['CODEUT'] == codeut) & (df_danone['CODEDT'] == codedt)]
        if not match2.empty:
            return match2['Ingreso'].iloc[0]
    
    return None

# Aplicar função
df['ingresso_danone'] = df.apply(buscar_ingreso_danone, axis=1)

# Estatísticas
total_linhas = len(df)
matches = df['ingresso_danone'].notna().sum()
sum_ingresso_danone = df['ingresso_danone'].sum()
sum_ingreso_excel = df_danone['Ingreso'].sum()

print(f"Total de linhas df: {total_linhas}")
print(f"Matches encontrados: {matches}")
print(f"Taxa sucesso: {(matches/total_linhas*100):.2f}%")
print(f"\nSum ingresso_danone: {sum_ingresso_danone:,.2f}")
print(f"Sum Ingreso Excel: {sum_ingreso_excel:,.2f}")
print(f"Diferença: {(sum_ingreso_excel - sum_ingresso_danone):,.2f}")

df[['CODEDT', 'REFERENCIA', 'CODEUT', 'INGRESODT', 'ingresso_danone']].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 37
#      33
#      34     return None
#      35
#      36 # Aplicar função
# ---> 37 df['ingresso_danone'] = df.apply(buscar_ingreso_danone, axis=1)
#      38
#      39 # Estatísticas
#      40 total_linhas = len(df)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\frame.py:12435, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   12431                 engine_kwargs=engine_kwargs,
#   12432                 args=args,
#   12433                 kwargs=kwargs,
#   12434             )
# > 12435             return op.apply().__finalize__(self, method="apply")
#   12436         elif hasattr(engine, "__pandas_udf__"):
#   12437             if result_type is not None:
#   12438                 raise NotImplementedError(
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\apply.py:1015, in FrameApply.apply(self)
#    1012 elif self.raw:
#    1013     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# -> 1015 return self.apply_standard()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\apply.py:1167, in FrameApply.apply_standard(self)
#    1165 def apply_standard(self):
#    1166     if self.engine == "python":
# -> 1167         results, res_index = self.apply_series_generator()
#    1168     else:
#    1169         results, res_index = self.apply_series_numba()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\apply.py:1183, in FrameApply.apply_series_generator(self)
#    1180 results = {}
#    1182 for i, v in enumerate(series_gen):
# -> 1183     results[i] = self.func(v, *self.args, **self.kwargs)
#    1184     if isinstance(results[i], ABCSeries):
#    1185         # If we have a view on v, we need to make a copy because
#    1186         #  series_generator will swap out the underlying data
#    1187         results[i] = results[i].copy(deep=False)
#
# Cell In[10], line 24, in buscar_ingreso_danone(row)
#      20     referencia = str(row['REFERENCIA']).strip()
#      21     codedt = int(row['CODEDT']) if pd.notna(row['CODEDT']) else None
#      22
#      23     # Tentativa 1: CODEUT + REFERENCIA
# ---> 24     match1 = df_danone[(df_danone['CODEUT'] == codeut) & (df_danone['REFERENCIA'] == referencia)]
#      25     if not match1.empty:
#      26         return match1['Ingreso'].iloc[0]
#      27
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\frame.py:4369, in DataFrame.__getitem__(self, key)
#    4365             return self.where(key)
#    4366
#    4367         # Do we have a (boolean) 1d indexer?
#    4368         if com.is_bool_indexer(key):
# -> 4369             return self._getitem_bool_array(key)
#    4370
#    4371         # We are left with two options: a single key, and a collection of keys,
#    4372         # We interpret tuples as collections only for non-MultiIndex
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\frame.py:4431, in DataFrame._getitem_bool_array(self, key)
#    4427         if key.all():
#    4428             return self.copy(deep=False)
#    4429
#    4430         indexer = key.nonzero()[0]
# -> 4431         return self.take(indexer, axis=0)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\generic.py:4101, in NDFrame.take(self, indices, axis, **kwargs)
#    4097         indices = np.asarray(indices, dtype=np.intp)
#    4098         if axis == 0 and indices.ndim == 1 and is_range_indexer(indices, len(self)):
#    4099             return self.copy(deep=False)
#    4100
# -> 4101         new_data = self._mgr.take(
#    4102             indices,
#    4103             axis=self._get_block_manager_axis(axis),
#    4104             verify=True,
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\internals\managers.py:1077, in BaseBlockManager.take(self, indexer, axis, verify)
#    1074 indexer = maybe_convert_indices(indexer, n, verify=verify)
#    1076 new_labels = self.axes[axis].take(indexer)
# -> 1077 return self.reindex_indexer(
#    1078     new_axis=new_labels,
#    1079     indexer=indexer,
#    1080     axis=axis,
#    1081     allow_dups=True,
#    1082 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\internals\managers.py:866, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, only_slice, use_na_proxy)
#     863             new_blocks.append(NumpyBlock(vals, blk.mgr_locs, ndim=2))
#     864         else:
#     865             new_blocks.append(
# --> 866                 blk.take_nd(
#     867                     indexer,
#     868                     axis=1,
#     869                     fill_value=(
#     870                         fill_value if fill_value is not None else blk.fill_value
#     871                     ),
#     872                 )
#     873             )
#     875 new_axes = list(self.axes)
#     876 new_axes[axis] = new_axis
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\internals\blocks.py:1015, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1012     allow_fill = True
#    1014 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1015 new_values = algos.take_nd(
#    1016     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1017 )
#    1019 # Called from three places in managers, all of which satisfy
#    1020 #  these assertions
#    1021 if isinstance(self, ExtensionBlock):
#    1022     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1023     #  algos.take_nd call above.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\array_algos\take.py:112, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     107         arr = cast("NDArrayBackedExtensionArray", arr)
#     108         return arr.take(
#     109             indexer, fill_value=fill_value, allow_fill=allow_fill, axis=axis
#     110         )
# --> 112     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     114 arr = np.asarray(arr)
#     115 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\arrays\arrow\array.py:1634, in ArrowExtensionArray.take(self, indices, allow_fill, fill_value)
#    1630         return result
#    1631         # return type(self)(pc.fill_null(result, pa.scalar(fill_value)))
#    1632     else:
#    1633         # Nothing to fill
# -> 1634         return self._from_pyarrow_array(self._pa_array.take(indices))
#    1635 else:  # allow_fill=False
#    1636     # TODO(ARROW-9432): Treat negative indices as indices from the right.
#    1637     if (indices_array < 0).any():
#    1638         # Don't modify in-place
#
# File pyarrow/table.pxi:1083, in pyarrow.lib.ChunkedArray.take()
# -> 1083 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pyarrow\compute.py:508, in take(data, indices, boundscheck, memory_pool)
#     468 """
#     469 Select values (or records) from array- or table-like data given integer
#     470 selection indices.
#    (...)    505 ]
#     506 """
#     507 options = TakeOptions(boundscheck=boundscheck)
# --> 508 return call_function('take', [data, indices], options, memory_pool)
#
# KeyboardInterrupt:

# %%
# Número de DT (linhas) por mês

print("="*70)
print("DISTRIBUIÇÃO DE DT POR MÊS")
print("="*70)

# Extrair mês de FCARGA
df['mes'] = pd.to_datetime(df['FENTREGA']).dt.month
df['mes_nome'] = pd.to_datetime(df['FENTREGA']).dt.strftime('%B')

# Contar por mês
dt_por_mes = df['mes'].value_counts().sort_index()

print("\nNúmero de DT por mês:")
for mes, count in dt_por_mes.items():
    mes_nome = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'][mes-1]
    pct = (count / len(df) * 100)
    print(f"  {mes_nome}: {count:>6} DT ({pct:>5.2f}%)")

print(f"\nTotal: {len(df)} DT")
# Out:
# ======================================================================
# DISTRIBUIÇÃO DE DT POR MÊS
# ======================================================================
#
# Número de DT por mês:
#   Jan:  14122 DT (13.05%)
#   Fev:  13466 DT (12.44%)
#   Mar:  14862 DT (13.73%)
#   Abr:  15001 DT (13.86%)
#   Mai:  14811 DT (13.69%)
#   Jun:  14815 DT (13.69%)
#   Jul:  16737 DT (15.47%)
#   Ago:   4405 DT ( 4.07%)
#
# Total: 108219 DT

# %% [markdown]
# Calculos auxiliares

# %%
# Criar novas colunas antes de exportar para parquet

# Converter FCARGA para datetime para extrair informações
df['data'] = pd.to_datetime(df['FCARGA'])

# Week number (ISO week)
df['week_number'] = df['data'].dt.isocalendar().week

# Week day (0=Segunda, 6=Domingo)
df['week_day'] = df['data'].dt.day_name()

# Total ingresso = ingresso_danone + INGRESODT
df['total_ingresso'] = df['ingresso_danone'].fillna(0) / 2 + df['INGRESODT']

print("Colunas criadas:")
print(f"  ✓ week_number")
print(f"  ✓ week_day")
print(f"  ✓ total_ingresso")

print(f"\nExemplos:")
df[['FCARGA', 'week_number', 'week_day', 'INGRESODT', 'ingresso_danone', 'total_ingresso']].head(10)
# Out:
# Colunas criadas:
#   ✓ week_number
#   ✓ week_day
#   ✓ total_ingresso
#
# Exemplos:
#        FCARGA  week_number week_day  INGRESODT  ingresso_danone  \
# 0  2025-12-29            1   Monday      10.69              NaN
# 1  2025-12-29            1   Monday     125.04              NaN
# 2  2025-12-30            1  Tuesday       0.00              NaN
# 3  2025-12-30            1  Tuesday       0.00              NaN
# 4  2025-12-30            1  Tuesday       0.00              NaN
# 5  2025-12-30            1  Tuesday       0.00              NaN
# 6  2025-12-30            1  Tuesday       0.00              NaN
# 7  2025-12-30            1  Tuesday       0.00              NaN
# 8  2026-01-02            1   Friday      23.54              NaN
# 9  2026-01-02            1   Friday      15.07              NaN
#
#    total_ingresso
# 0           10.69
# 1          125.04
# 2            0.00
# 3            0.00
# 4            0.00
# 5            0.00
# 6            0.00
# 7            0.00
# 8           23.54
# 9           15.07

# %% [markdown]
# tratamento antes das metricas

# %%
# Garantir que capacidade_norm existe
if 'capacidade_norm' not in df.columns:
    print("Criando capacidade_norm...")
    
    # Converter para número
    df['CAMION_CAPACIDAD_NUM'] = pd.to_numeric(df['CAMION_CAPACIDAD'], errors='coerce')
    
    # Mapeamento de normalização
    mapeamento = {
        4: 6, 5: 6, 6: 6,
        8: 12, 12: 12,
        14: 20, 15: 20, 16: 20, 18: 20, 20: 20,
        22: 24, 24: 24,
        33: 33, 66: 66
    }
    
    # Aplicar mapeamento
    df['capacidade_norm'] = df['CAMION_CAPACIDAD_NUM'].map(mapeamento)
    
    # Tratar zeros
    linhas_zero = df['CAMION_CAPACIDAD_NUM'] == 0
    if linhas_zero.sum() > 0:
        capacidade_por_codeut = df[df['CAMION_CAPACIDAD_NUM'] > 0].groupby('CODEUT')['capacidade_norm'].agg(lambda x: x.mode()[0] if len(x.mode()) > 0 else x.max())
        for cu in df[linhas_zero]['CODEUT'].unique():
            if cu in capacidade_por_codeut.index:
                df.loc[(df['CODEUT'] == cu) & linhas_zero, 'capacidade_norm'] = capacidade_por_codeut[cu]

# Criar coluna indicadora
df['dados_validos'] = df['capacidade_norm'].notna()

print("="*80)
print("MARCAÇÃO DE DADOS")
print("="*80)

print(f"Total linhas: {len(df):,}")
print(f"Dados válidos: {df['dados_validos'].sum():,}")
print(f"Dados incompletos (ignorar): {(~df['dados_validos']).sum():,}")

print(f"\n--- Cálculos usarão apenas linhas com dados_validos = True ---")
# Out:
# Criando capacidade_norm...
# ================================================================================
# MARCAÇÃO DE DADOS
# ================================================================================
# Total linhas: 108,219
# Dados válidos: 107,958
# Dados incompletos (ignorar): 261
#
# --- Cálculos usarão apenas linhas com dados_validos = True ---

# %% [markdown]
# Coordenadas

# %%
# Ler ficheiro de coordenadas
import platform
if platform.system() == 'Windows':
    coords_path = r"C:\Users\LISARR\Documents\python\00.Metadados\CP7COORDS_FORMATADO.CSV"
elif platform.system() == 'Darwin':
    coords_path = "/Volumes/RR/DB/CP7COORDS_FORMATADO.CSV"
else:
    coords_path = "CP7COORDS_FORMATADO.CSV"

coords = pd.read_csv(coords_path, sep=';', encoding='utf-8')
coords['POINT_X'] = coords['POINT_X'].str.replace(',', '.').astype(float)
coords['POINT_Y'] = coords['POINT_Y'].str.replace(',', '.').astype(float)

print(f"Coordenadas carregadas: {len(coords):,} registos")
# Out:
# Coordenadas carregadas: 178,409 registos

# %%
# Calcular centroid por primeira parte do CP
coords['CP_parte'] = coords['CP'].str.split('-').str[0]
coords_centroid = coords.groupby('CP_parte')[['POINT_X', 'POINT_Y']].mean().reset_index()
coords_centroid.columns = ['CP_parte', 'longitude_centroid', 'latitude_centroid']

coords_centroid.head()
# Out:
#   CP_parte  longitude_centroid  latitude_centroid
# 0     1000           -9.139397          38.738262
# 1     1050           -9.149352          38.734860
# 2     1070           -9.164875          38.729817
# 3     1100           -9.131875          38.713056
# 4     1150           -9.140143          38.722876

# %%
# Calcular centroid por primeira parte do CP
coords['CP_parte'] = coords['CP'].str.split('-').str[0]
centroid = coords.groupby('CP_parte')[['POINT_X', 'POINT_Y']].mean().reset_index()
centroid.columns = ['CP_parte', 'longitude_centroid', 'latitude_centroid']

# Preparar dados para origem
coords_origem = coords[['CP', 'POINT_X', 'POINT_Y']].copy()
coords_origem.columns = ['CPOSTAL', 'longitude_origem', 'latitude_origem']

# Preparar dados para destino
coords_destino = coords[['CP', 'POINT_X', 'POINT_Y']].copy()
coords_destino.columns = ['CPOSTAD', 'longitude_destino', 'latitude_destino']

# Remover colunas de coordenadas se já existem (de execuções anteriores)
cols_remover = ['longitude_origem', 'latitude_origem', 'longitude_destino', 'latitude_destino', 'CPOSTAL_parte', 'CPOSTAD_parte']
df = df.drop(columns=[c for c in cols_remover if c in df.columns])

df['CPOSTAL_parte'] = df['CPOSTAL'].str.split('-').str[0]
df['CPOSTAD_parte'] = df['CPOSTAD'].str.split('-').str[0]

# Join origem e destino (como estava)
df = df.merge(coords_origem, on='CPOSTAL', how='left')
df = df.merge(coords_destino, on='CPOSTAD', how='left')

# Preencher NaN com centroid origem
df = df.merge(centroid.rename(columns={'CP_parte': 'CPOSTAL_parte', 'longitude_centroid': 'longitude_origem_c', 'latitude_centroid': 'latitude_origem_c'}), on='CPOSTAL_parte', how='left')
df.loc[df['longitude_origem'].isna(), 'longitude_origem'] = df.loc[df['longitude_origem'].isna(), 'longitude_origem_c']
df.loc[df['latitude_origem'].isna(), 'latitude_origem'] = df.loc[df['latitude_origem'].isna(), 'latitude_origem_c']

# Preencher NaN com centroid destino
df = df.merge(centroid.rename(columns={'CP_parte': 'CPOSTAD_parte', 'longitude_centroid': 'longitude_destino_c', 'latitude_centroid': 'latitude_destino_c'}), on='CPOSTAD_parte', how='left')
df.loc[df['longitude_destino'].isna(), 'longitude_destino'] = df.loc[df['longitude_destino'].isna(), 'longitude_destino_c']
df.loc[df['latitude_destino'].isna(), 'latitude_destino'] = df.loc[df['latitude_destino'].isna(), 'latitude_destino_c']

# Remover colunas temporárias
df = df.drop(columns=['CPOSTAL_parte', 'CPOSTAD_parte', 'longitude_origem_c', 'latitude_origem_c', 'longitude_destino_c', 'latitude_destino_c'])

print(f"Matches origem: {df['longitude_origem'].notna().sum():,}")
print(f"Matches destino: {df['longitude_destino'].notna().sum():,}")
# Out:
# Matches origem: 107,266
# Matches destino: 87,588

# %% [markdown]
# Cálculos

# %% [markdown]
# # Configurar pandas para ver tudo
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
# pd.set_option('display.width', None)
# pd.set_option('display.max_colwidth', None)
#
# # Calcular colunas derivadas
# df['custo_por_palete'] = df['COSTEDT'] / df['PALETS'].replace(0, 1)
#
# df['ingresso_por_palete'] = df['total_ingresso'] / df['PALETS'].replace(0, 1)
#
# # Totais por rota (CODEUT)
# rota_totais = df.groupby('CODEUT').agg({
#     'PALETS': 'sum',
#     'capacidade_norm': 'first'
# }).reset_index()
# rota_totais.columns = ['CODEUT', 'total_palets', 'capacidade_rota']
#
# # Taxa da rota
# rota_totais['taxa_rota'] = (rota_totais['total_palets'] / rota_totais['capacidade_rota'].replace(0, 1)) * 100
#
# # Aplicar merge para trazer taxa_rota e total_palets para o df principal
# df = df.merge(rota_totais[['CODEUT', 'taxa_rota', 'total_palets']], on='CODEUT', how='left')
#
# # Taxa por linha (proporcional à rota)
# df['taxa_ocupacao'] = (df['PALETS'] / df['total_palets'].replace(0, 1)) * df['taxa_rota']
#
# # Limpar temporárias
# df = df.drop(columns=['taxa_rota', 'total_palets'])
#
# # Margem
# df['margem'] = df['ingresso_por_palete'] - df['COSTEDT']

# %%
# Configurar pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# 1️⃣ Custo por palete
df['custo_por_palete'] = df['COSTEDT'] / df['PALETS'].replace(0, 1)

# 2️⃣ Ingresso por palete (com Danone via total_ingresso)
df['ingresso_por_palete'] = df['total_ingresso'] / df['PALETS'].replace(0, 1)

# 3️⃣ Taxa de ocupação por rota (CODEUT)
rota_totais = df.groupby('CODEUT').agg({
    'PALETS': 'sum',
    'capacidade_norm': 'first'
}).reset_index()
rota_totais.columns = ['CODEUT', 'total_palets', 'capacidade_rota']

rota_totais['taxa_rota'] = (rota_totais['total_palets'] / rota_totais['capacidade_rota'].replace(0, 1)) * 100

df = df.merge(rota_totais[['CODEUT', 'taxa_rota', 'total_palets']], on='CODEUT', how='left')

df['taxa_ocupacao'] = (df['PALETS'] / df['total_palets'].replace(0, 1)) * df['taxa_rota']

# Limpar colunas temporárias
df = df.drop(columns=['taxa_rota', 'total_palets'])

# 4️⃣ Margem (total_ingresso - COSTEDT, unidades corretas)
df['margem'] = df['total_ingresso'] - df['COSTEDT']

# 5️⃣ Margem por palete
df['margem_por_palete'] = df['ingresso_por_palete'] - df['custo_por_palete']

df.head()
# Out:
#    id PROPIETARIO  \
# 0   1         CEP
# 1   2         CEP
# 2   3         CEP
# 3   4         CEP
# 4   5         CEP
#
#                                                                                                                                                    TRAYECTO  \
# 0                                      SALVESEN LOGISTICA PORTUGAL / SALVESEN LOGISTICA AZAMBUJA 2 / PLAT. COOPLECNORTE,S.A. / COOPLECNORTE-OLIVEIRA BAIRRO
# 1                                      SALVESEN LOGISTICA PORTUGAL / SALVESEN LOGISTICA AZAMBUJA 2 / PLAT. COOPLECNORTE,S.A. / COOPLECNORTE-OLIVEIRA BAIRRO
# 2  SALVESEN LOGISTICA PORTUGAL / SALVESEN LOGISTICA AZAMBUJA 2 / DL Transportes Fernando Simões Monteiro Unip. Lda / NO USAR TRANP.FERNANDO SIMÕES MONTEIRO
# 3  SALVESEN LOGISTICA PORTUGAL / SALVESEN LOGISTICA AZAMBUJA 2 / DL Transportes Fernando Simões Monteiro Unip. Lda / NO USAR TRANP.FERNANDO SIMÕES MONTEIRO
# 4  SALVESEN LOGISTICA PORTUGAL / SALVESEN LOGISTICA AZAMBUJA 2 / DL Transportes Fernando Simões Monteiro Unip. Lda / NO USAR TRANP.FERNANDO SIMÕES MONTEIRO
#
#                                     TRANSPORTISTA TRACTORA REMOLQUE  \
# 0                                SOLIDO CLICK LDA  0000XXX  0000XXX
# 1                                SOLIDO CLICK LDA  0000XXX  0000XXX
# 2  Transportes Fernando Simões Monteiro Unip. Lda  0000XXX  0000XXX
# 3  Transportes Fernando Simões Monteiro Unip. Lda  0000XXX  0000XXX
# 4  Transportes Fernando Simões Monteiro Unip. Lda  0000XXX  0000XXX
#
#    INGRESODT  COSTEDT  RENTADT  PALETSDT  PESO_BRUTO   CODEUT ESTADO_UT  \
# 0      10.69     4.64     6.05      0.49      227.26  3344051        30
# 1     125.04   236.86  -111.82     25.00     2719.88  3344051        30
# 2       0.00    12.02   -12.02      0.80      487.26  3344052        30
# 3       0.00    10.82   -10.82      0.72      423.44  3344052        30
# 4       0.00     6.01    -6.01      0.40      236.29  3344052        30
#
#   RANGO_UT      FCARGA        ACTIVIDAD    CODEDT ESTADO_DT  \
# 0        1  2025-12-29  DANONE PORTUGAL  25387086        70
# 1        1  2025-12-29  DANONE PORTUGAL  25398553        70
# 2        2  2025-12-30  DANONE PORTUGAL  25392919        70
# 3        2  2025-12-30  DANONE PORTUGAL  25393741        70
# 4        2  2025-12-30  DANONE PORTUGAL  25393743        70
#
#                  REFERENCIA CODACT            LOCORIGEN PROV_ORIGEN  \
# 0  5021705579     413948820    011  Vila Nova da Rainha      Lisboa
# 1  5021695753     413975730    011  Vila Nova da Rainha      Lisboa
# 2  5021718153     413962673    011  Vila Nova da Rainha      Lisboa
# 3  5021741334     413968895    011  Vila Nova da Rainha      Lisboa
# 4  5021740631     413963593    011  Vila Nova da Rainha      Lisboa
#
#   PAISORIGEN   CPOSTAL          LOCDESTINO PROV_DESTINO PAISDESTINO   CPOSTAD  \
# 0   PORTUGAL  2050-540  Oliveira do Bairro       Aveiro    PORTUGAL  3770-305
# 1   PORTUGAL  2050-540  Oliveira do Bairro       Aveiro    PORTUGAL  3770-305
# 2   PORTUGAL  2050-540     Condeixa-a-Nova      Coimbra    PORTUGAL  3150-020
# 3   PORTUGAL  2050-540     Condeixa-a-Nova      Coimbra    PORTUGAL  3150-020
# 4   PORTUGAL  2050-540     Condeixa-a-Nova      Coimbra    PORTUGAL  3150-020
#
#    KM    FENTREGA                                                     ORIGEN  \
# 0 NaN  2026-01-02        SALVESEN LOGISTICA PORTUGAL / Danone Portugal (011)
# 1 NaN  2026-01-02        SALVESEN LOGISTICA PORTUGAL / Danone Portugal (011)
# 2 NaN  2026-01-02  SALVESEN LOGISTICA PORTUGAL / Hijos de Juan Pujante (208)
# 3 NaN  2026-01-02  SALVESEN LOGISTICA PORTUGAL / Hijos de Juan Pujante (208)
# 4 NaN  2026-01-02  SALVESEN LOGISTICA PORTUGAL / Hijos de Juan Pujante (208)
#
#                             ENTREGAR PROV_ENTREGAR PAISENTREGAR  \
# 0            PLAT. COOPLECNORTE,S.A.        Aveiro     PORTUGAL
# 1            PLAT. COOPLECNORTE,S.A.        Aveiro     PORTUGAL
# 2  3. MARABUTO-PRODUT.ALIMENTARES,SA        Aveiro     PORTUGAL
# 3  3. O NOVO CASH-STA MARIA DA FEIRA        Aveiro     PORTUGAL
# 4     3.NEOMÁQUINA SUPER. LDA - LJ 1        Leiria     PORTUGAL
#
#                                                  DESTINO  PALETS PREFAC  RUTA  \
# 0                   COOPLECNORTE / Danone Portugal (011)     1.0    GEN  1000
# 1                   COOPLECNORTE / Danone Portugal (011)    25.0    GEN  1000
# 2  TRANP.FERNANDO SIMÕES MONTEIRO / Alpro Portugal (311)     1.0    GEN  7720
# 3  TRANP.FERNANDO SIMÕES MONTEIRO / Alpro Portugal (311)     1.0    GEN  2103
# 4  TRANP.FERNANDO SIMÕES MONTEIRO / Alpro Portugal (311)     1.0    GEN  7720
#
#   COBROREAL GESTION DEPART   USCODE           USUARIO   TIPOCLIENTE TIPOFLUJO  \
# 0         0     LIS      D  LISANSL  Nuno Santos Lima  TLD PORTUGAL   Directo
# 1         0     LIS      D  LISANSL  Nuno Santos Lima  TLD PORTUGAL   Directo
# 2         0     LIS      D  LISANSL  Nuno Santos Lima  TLD PORTUGAL       DLS
# 3         0     LIS      D  LISANSL  Nuno Santos Lima  TLD PORTUGAL       DLS
# 4         0     LIS      D  LISANSL  Nuno Santos Lima  TLD PORTUGAL       DLS
#
#   WMSCODRGT  LOCCAR                   LUGARCARGA  LOCDES  \
# 0       B12  137998  SALVESEN LOGISTICA PORTUGAL  573897
# 1       B12  137998  SALVESEN LOGISTICA PORTUGAL  573897
# 2       B12  137998  SALVESEN LOGISTICA PORTUGAL  298515
# 3       B12  137998  SALVESEN LOGISTICA PORTUGAL  298515
# 4       B12  137998  SALVESEN LOGISTICA PORTUGAL  298515
#
#                                        LUGARDESCARGA TEMP_MERC_PED TIPOPALETA  \
# 0                            PLAT. COOPLECNORTE,S.A.        RFGRFG        EUR
# 1                            PLAT. COOPLECNORTE,S.A.        RFGRFG        EUR
# 2  DL Transportes Fernando Simões Monteiro Unip. Lda        RFGRFG        EUR
# 3  DL Transportes Fernando Simões Monteiro Unip. Lda        RFGRFG        EUR
# 4  DL Transportes Fernando Simões Monteiro Unip. Lda        RFGRFG        EUR
#
#        CAMION_TIPO CAMION_CAPACIDAD TIPO_COMBUSTIBLE  KMREALES ALBARAN  \
# 0  Trailer 33 plts               33           DIESEL   194.134      NO
# 1  Trailer 33 plts               33           DIESEL   194.134      NO
# 2  Trailer 33 plts               33           DIESEL   151.803      NO
# 3  Trailer 33 plts               33           DIESEL   151.803      NO
# 4  Trailer 33 plts               33           DIESEL   151.803      NO
#
#        ficheiro_origem  ingresso_danone  mes mes_nome       data  week_number  \
# 0  SAL_DAT027 (11).xls              NaN    1  January 2025-12-29            1
# 1  SAL_DAT027 (11).xls              NaN    1  January 2025-12-29            1
# 2  SAL_DAT027 (11).xls              NaN    1  January 2025-12-30            1
# 3  SAL_DAT027 (11).xls              NaN    1  January 2025-12-30            1
# 4  SAL_DAT027 (11).xls              NaN    1  January 2025-12-30            1
#
#   week_day  total_ingresso  CAMION_CAPACIDAD_NUM  capacidade_norm  \
# 0   Monday           10.69                    33             33.0
# 1   Monday          125.04                    33             33.0
# 2  Tuesday            0.00                    33             33.0
# 3  Tuesday            0.00                    33             33.0
# 4  Tuesday            0.00                    33             33.0
#
#    dados_validos  longitude_origem  latitude_origem  longitude_destino  \
# 0           True         -8.920854        39.047635          -8.523268
# 1           True         -8.920854        39.047635          -8.523268
# 2           True         -8.920854        39.047635          -8.531480
# 3           True         -8.920854        39.047635          -8.531480
# 4           True         -8.920854        39.047635          -8.531480
#
#    latitude_destino  custo_por_palete  ingresso_por_palete  margem  \
# 0         40.512134            4.6400              10.6900    6.05
# 1         40.512134            9.4744               5.0016 -111.82
# 2         40.167186           12.0200               0.0000  -12.02
# 3         40.167186           10.8200               0.0000  -10.82
# 4         40.167186            6.0100               0.0000   -6.01
#
#    margem_por_palete  taxa_ocupacao
# 0             6.0500       3.030303
# 1            -4.4728      75.757576
# 2           -12.0200       3.030303
# 3           -10.8200       3.030303
# 4            -6.0100       3.030303

# %%
# Lista de colunas finais
colunas_finais = [
    'FENTREGA', 'CODEUT', 'capacidade_norm', 'PALETS', 'INGRESODT', 'total_ingresso', 'COSTEDT',
    'PROV_ORIGEN', 'LOCORIGEN', 'PROV_DESTINO', 'LOCDESTINO', 'CPOSTAL', 'CPOSTAD',
    'TRANSPORTISTA', 'week_day', 'week_number', 'mes', 'mes_nome', 'data',
    'dados_validos', 'LOCCAR', 'LUGARCARGA', 'LOCDES', 'LUGARDESCARGA', 'TRACTORA',
    'PESO_BRUTO', 'CODEDT', 'CODACT', 'TIPOCLIENTE', 'TIPOFLUJO',
    'PROV_ENTREGAR', 'PAISENTREGAR', 'ACTIVIDAD',
    'custo_por_palete', 'ingresso_por_palete', 'taxa_ocupacao', 'margem'
]

# Selecionar colunas
df_sel = df[colunas_finais].copy()

print(f"df_sel criado: {len(df_sel):,} linhas x {len(df_sel.columns)} colunas")
print(f"CPOSTAL únicos: {df_sel['CPOSTAL'].nunique()}")
# Out:
# df_sel criado: 108,219 linhas x 37 colunas
# CPOSTAL únicos: 153

# %%
df_sel.head(5)
# Out:
#      FENTREGA   CODEUT  capacidade_norm  PALETS  INGRESODT  total_ingresso  \
# 0  2026-01-02  3344051             33.0     1.0      10.69           10.69
# 1  2026-01-02  3344051             33.0    25.0     125.04          125.04
# 2  2026-01-02  3344052             33.0     1.0       0.00            0.00
# 3  2026-01-02  3344052             33.0     1.0       0.00            0.00
# 4  2026-01-02  3344052             33.0     1.0       0.00            0.00
#
#    COSTEDT PROV_ORIGEN            LOCORIGEN PROV_DESTINO          LOCDESTINO  \
# 0     4.64      Lisboa  Vila Nova da Rainha       Aveiro  Oliveira do Bairro
# 1   236.86      Lisboa  Vila Nova da Rainha       Aveiro  Oliveira do Bairro
# 2    12.02      Lisboa  Vila Nova da Rainha      Coimbra     Condeixa-a-Nova
# 3    10.82      Lisboa  Vila Nova da Rainha      Coimbra     Condeixa-a-Nova
# 4     6.01      Lisboa  Vila Nova da Rainha      Coimbra     Condeixa-a-Nova
#
#     CPOSTAL   CPOSTAD                                   TRANSPORTISTA  \
# 0  2050-540  3770-305                                SOLIDO CLICK LDA
# 1  2050-540  3770-305                                SOLIDO CLICK LDA
# 2  2050-540  3150-020  Transportes Fernando Simões Monteiro Unip. Lda
# 3  2050-540  3150-020  Transportes Fernando Simões Monteiro Unip. Lda
# 4  2050-540  3150-020  Transportes Fernando Simões Monteiro Unip. Lda
#
#   week_day  week_number  mes mes_nome       data  dados_validos  LOCCAR  \
# 0   Monday            1    1  January 2025-12-29           True  137998
# 1   Monday            1    1  January 2025-12-29           True  137998
# 2  Tuesday            1    1  January 2025-12-30           True  137998
# 3  Tuesday            1    1  January 2025-12-30           True  137998
# 4  Tuesday            1    1  January 2025-12-30           True  137998
#
#                     LUGARCARGA  LOCDES  \
# 0  SALVESEN LOGISTICA PORTUGAL  573897
# 1  SALVESEN LOGISTICA PORTUGAL  573897
# 2  SALVESEN LOGISTICA PORTUGAL  298515
# 3  SALVESEN LOGISTICA PORTUGAL  298515
# 4  SALVESEN LOGISTICA PORTUGAL  298515
#
#                                        LUGARDESCARGA TRACTORA  PESO_BRUTO  \
# 0                            PLAT. COOPLECNORTE,S.A.  0000XXX      227.26
# 1                            PLAT. COOPLECNORTE,S.A.  0000XXX     2719.88
# 2  DL Transportes Fernando Simões Monteiro Unip. Lda  0000XXX      487.26
# 3  DL Transportes Fernando Simões Monteiro Unip. Lda  0000XXX      423.44
# 4  DL Transportes Fernando Simões Monteiro Unip. Lda  0000XXX      236.29
#
#      CODEDT CODACT   TIPOCLIENTE TIPOFLUJO PROV_ENTREGAR PAISENTREGAR  \
# 0  25387086    011  TLD PORTUGAL   Directo        Aveiro     PORTUGAL
# 1  25398553    011  TLD PORTUGAL   Directo        Aveiro     PORTUGAL
# 2  25392919    011  TLD PORTUGAL       DLS        Aveiro     PORTUGAL
# 3  25393741    011  TLD PORTUGAL       DLS        Aveiro     PORTUGAL
# 4  25393743    011  TLD PORTUGAL       DLS        Leiria     PORTUGAL
#
#          ACTIVIDAD  custo_por_palete  ingresso_por_palete  taxa_ocupacao  \
# 0  DANONE PORTUGAL            4.6400              10.6900       3.030303
# 1  DANONE PORTUGAL            9.4744               5.0016      75.757576
# 2  DANONE PORTUGAL           12.0200               0.0000       3.030303
# 3  DANONE PORTUGAL           10.8200               0.0000       3.030303
# 4  DANONE PORTUGAL            6.0100               0.0000       3.030303
#
#    margem
# 0    6.05
# 1 -111.82
# 2  -12.02
# 3  -10.82
# 4   -6.01

# %% [markdown]
# Exportar ficheiro

# %%
caminho_parquet = r"C:\Users\LISARR\Documents\python\01.Financeiro\inform_27_2026_final.parquet"

# Exportar para parquet
df_sel.to_parquet(caminho_parquet, index=False)

print(f"✅ Ficheiro exportado: {caminho_parquet}")
print(f"Linhas: {len(df_sel)}")
print(f"Colunas: {len(df_sel.columns)}")
print(f"Tamanho: {df_sel.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
# Out:
# ✅ Ficheiro exportado: C:\Users\LISARR\Documents\python\01.Financeiro\inform_27_2026_final.parquet
# Linhas: 108219
# Colunas: 37
# Tamanho: 55.67 MB

# %% [markdown]
# import sqlite3
#
# # Conectar à BD
# if platform.system() == 'Windows':
#     DB_PATH = r"C:\Users\LISARR\Documents\python\01.Financeiro\inform_27.db"
# elif platform.system() == 'Darwin':
#     DB_PATH = "/Volumes/RR/DB/inform_27.db"
# else:
#     DB_PATH = "inform_27.db"
#
# con = sqlite3.connect(DB_PATH)
#
# # Ler tabela km_diario_2026
# km_diario = pd.read_sql_query("SELECT * FROM km_diario_2026", con)
# con.close()
#
# print(f"km_diario_2026 carregada: {len(km_diario):,} linhas")
#
# # Converter data para datetime
# km_diario['data'] = pd.to_datetime(km_diario['data'])
#
# # Renomear coluna trator para TRACTORA para match
# km_diario.rename(columns={'trator': 'TRACTORA'}, inplace=True)
#
# # Converter TRACTORA em df_sel para datetime (se necessário)
# df_sel['data'] = pd.to_datetime(df_sel['data'])
#
# # Join: data + TRACTORA
# df_merged = df_sel.merge(
#     km_diario[['TRACTORA', 'data', 'km']],
#     on=['TRACTORA', 'data'],
#     how='left'
# )
#
# # Verificar duplicatas (mesma matrícula, mesma data, múltiplos CODEUT)
# duplicatas = df_merged[df_merged.duplicated(subset=['TRACTORA', 'data'], keep=False)]
#
# if len(duplicatas) > 0:
#     print(f"\n⚠ Encontradas {len(duplicatas):,} linhas com múltiplos CODEUT por matrícula/data")
#     print("Distribuindo KM proporcionalmente...")
#
#     # Distribuir KM
#     for (tractor, data_val), group in df_merged.groupby(['TRACTORA', 'data']):
#         if len(group) > 1 and group['km'].notna().any():
#             km_total = group['km'].iloc[0]
#             km_distribuido = km_total / len(group)
#             df_merged.loc[(df_merged['TRACTORA'] == tractor) & (df_merged['data'] == data_val), 'km'] = km_distribuido
#
# print(f"\n✓ KM adicionado a df_sel")
# print(f"Linhas com KM: {df_merged['km'].notna().sum():,}")
# print(f"Total colunas: {len(df_merged.columns)}")
#
# # Atualizar df_sel
# df_sel = df_merged.copy()

# %% [markdown]
# # Verificar quantas linhas têm KM
# print("="*80)
# print("ANÁLISE DE KM")
# print("="*80)
#
# print(f"\nTotal linhas df_sel: {len(df_sel):,}")
# print(f"Linhas com KM: {df_sel['km'].notna().sum():,}")
# print(f"Linhas sem KM: {df_sel['km'].isna().sum():,}")
# print(f"Percentagem com KM: {(df_sel['km'].notna().sum() / len(df_sel) * 100):.2f}%")
#
# print(f"\n--- Estatísticas KM ---")
# print(df_sel['km'].describe())
